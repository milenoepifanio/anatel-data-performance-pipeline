# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.read_csv(
    r"C:\Users\Mileno\Downloads\PDI\data\temp\ods_csv\SCM2016_Banda_Larga_Fixa.csv",
    encoding="utf-8-sig"
)

print(df.head())
print(df.iloc[0])
# Out:
#   GRUPO ECONÔMICO                                      VARIÁVEL    2016-01  \
# 0           ALGAR  Indicador de Desempenho no Atendimento (IDA)  94.474776
# 1         GVT (*)  Indicador de Desempenho no Atendimento (IDA)  76.479057
# 2             NET  Indicador de Desempenho no Atendimento (IDA)  78.631411
# 3              OI  Indicador de Desempenho no Atendimento (IDA)   0.000000
# 4       SERCOMTEL  Indicador de Desempenho no Atendimento (IDA)  80.377574
#
#      2016-02    2016-03     2016-04    2016-05  2016-06    2016-07    2016-08  \
# 0  93.052206  92.405439   96.660629  98.086590   94.679  95.671870  88.504193
# 1  73.902661  69.924062         NaN        NaN      NaN        NaN        NaN
# 2  79.184711  77.216504   92.306580  92.173691   91.797  91.679732  91.472236
# 3   0.000000   0.000000    0.000000   0.000000    9.601  19.589429  10.610403
# 4  87.878788  92.647059  100.000000  71.472720   60.285  86.126894  76.585695
#
#    2016-09  2016-10    2016-11    2016-12
# 0   92.209   96.390  93.290807  85.212273
# 1      NaN      NaN        NaN        NaN
# 2   93.038   92.285  85.712717  86.502207
# 3   28.725   26.837  24.617096  15.186503
# 4  100.000   83.814  82.502914  92.857143
# GRUPO ECONÔMICO                                           ALGAR
# VARIÁVEL           Indicador de Desempenho no Atendimento (IDA)
# 2016-01                                               94.474776
# 2016-02                                               93.052206
# 2016-03                                               92.405439
# 2016-04                                               96.660629
# 2016-05                                                98.08659
# 2016-06                                                  94.679
# 2016-07                                                95.67187
# 2016-08                                               88.504193
# 2016-09                                                  92.209
# 2016-10                                                   96.39
# 2016-11                                               93.290807
# 2016-12                                               85.212273
# Name: 0, dtype: object

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.read_parquet(
    r"C:\Users\Mileno\Downloads\PDI\data\staging\long-files\SCM2016_Banda_Larga_Fixa_long.parquet",
    engine="fastparquet"
)

print(df.head())
print(df.iloc[0])
print(df.dtypes)
# Out:
#   grupo_economico                                      variavel  \
# 0           ALGAR  Indicador de Desempenho no Atendimento (IDA)
# 1           ALGAR  Indicador de Desempenho no Atendimento (IDA)
# 2           ALGAR  Indicador de Desempenho no Atendimento (IDA)
# 3           ALGAR  Indicador de Desempenho no Atendimento (IDA)
# 4           ALGAR  Indicador de Desempenho no Atendimento (IDA)
#
#   arquivo_origem        aba_origem modelo  ano_arquivo competencia      valor  \
# 0    SCM2016.ods  Banda_Larga_Fixa    SCM         2016     2016-01  94.474776
# 1    SCM2016.ods  Banda_Larga_Fixa    SCM         2016     2016-02  93.052206
# 2    SCM2016.ods  Banda_Larga_Fixa    SCM         2016     2016-03  92.405439
# 3    SCM2016.ods  Banda_Larga_Fixa    SCM         2016     2016-04  96.660629
# 4    SCM2016.ods  Banda_Larga_Fixa    SCM         2016     2016-05  98.086590
#
#         _ingestion_timestamp _processing_date  \
# 0 2026-05-26 20:51:28.418063       2026-05-26
# 1 2026-05-26 20:51:28.418063       2026-05-26
# 2 2026-05-26 20:51:28.418063       2026-05-26
# 3 2026-05-26 20:51:28.418063       2026-05-26
# 4 2026-05-26 20:51:28.418063       2026-05-26
#
#                        _record_hash
# 0  30380b8ddd6da75a052e9a798b050bf5
# 1  b09bf7de1304cf52a3362d925a6777d2
# 2  c357c01d7b5f594fda124c5abcac30e4
# 3  dc0289212503a6ca54c3f8dc456ffa64
# 4  5284ed914fb6d78f460cccd3b1a92e0b
# grupo_economico                                                ALGAR
# variavel                Indicador de Desempenho no Atendimento (IDA)
# arquivo_origem                                           SCM2016.ods
# aba_origem                                          Banda_Larga_Fixa
# modelo                                                           SCM
# ano_arquivo                                                     2016
# competencia                                                  2016-01
# valor                                                      94.474776
# _ingestion_timestamp                      2026-05-26 20:51:28.418063
# _processing_date                                          2026-05-26
# _record_hash                        30380b8ddd6da75a052e9a798b050bf5
# Name: 0, dtype: object
# grupo_economico                 object
# variavel                        object
# arquivo_origem                  object
# aba_origem                      object
# modelo                          object
# ano_arquivo                      int32
# competencia                     object
# valor                          float64
# _ingestion_timestamp    datetime64[ns]
# _processing_date                object
# _record_hash                    object
# dtype: object
