# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (4.44.0)
# Requirement already satisfied: certifi>=2026.2.25 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from selenium) (2026.4.22)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.7.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (26.1.0)
# Requirement already satisfied: sortedcontainers in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.15)
# Requirement already satisfied: outcome in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Requirement already satisfied: wsproto>=0.14 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (3.0)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\Users\mileno_epifanio\Downloads\PDI\.venv\Lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton
from selenium.webdriver.chrome.service import Service
import time
import os

# %%
def get_default_chrome_options(caminho_pasta):
    # Garante que a pasta existe
    os.makedirs(caminho_pasta, exist_ok=True)

    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")

    # Define configurações de download
    prefs = {
        "download.default_directory": os.path.abspath(caminho_pasta),
        "download.prompt_for_download": False,
        "directory_upgrade": True,
        "safebrowsing.enabled": True
    }

    options.add_experimental_option("prefs", prefs)

    return options

# %%
pasta_destino = "C:/Users/mileno_epifanio/Downloads/PDI/data/raw"

# %%
# Abre o site
driver = webdriver.Chrome(options=get_default_chrome_options(pasta_destino))

driver.get("https://dados.gov.br/dados/conjuntos-dados/indice-desempenho-atendimento")

# Espera os botões estarem visíveis e clica
wait = WebDriverWait(driver, 10)
wait.until(EC.element_to_be_clickable((By.XPATH, "//button[@aria-controls='collapse-organizacao']"))).click()
wait.until(EC.element_to_be_clickable((By.XPATH, "//button[@aria-controls='collapse-recursos']"))).click()

# Espera os elementos carregarem
time.sleep(2)  # ou use WebDriverWait com o seletor certo

# Corrige o seletor (TAG 'col-10' não existe — isso é uma classe!)
elementos = driver.find_elements(By.CLASS_NAME, "col-10")
print(elementos)

# Altere "sua-id-aqui" pelo valor real do ID do container onde estão os links
container = driver.find_elements(By.ID, "btnDownloadUrl")

print(container)

palavras_chave = ["SCM", "SMP", "STFC", "TV"]

for i in elementos:
    if any(palavra in i.text for palavra in palavras_chave):
        driver.execute_script("arguments[0].scrollIntoView(true);", i)
        print("🔍 Encontrado:", i.text)
        container_pai = i.find_element(By.ID, "btnDownloadUrl")
        container_pai.click()
        time.sleep(2)  # Aguarda carregamento se necessário
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.49")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.50")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.51")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.52")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.53")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.54")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.55")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.56")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.57")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.58")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.59")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.60")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.61")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.62")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.63")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.64")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.65")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.66")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.67")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.68")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.69")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.70 ...
# [<selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.76")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.77")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.78")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.79")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.80")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.81")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.82")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.83")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.84")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.85")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.86")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.87")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.88")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.89")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.90")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.91")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.92")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.93")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.94")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.95")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.96")>, <selenium.webdriver.remote.webelement.WebElement (session="9d31718265f3b287c1cdbd4620d6e282", element="f.7317EC70BF3DEE53E301421263693724.d.43D190CA3A3245F9F5F0D75C5D0D0C37.e.97 ...
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SCM - 2015
# Do Serviço de Comunicação Multimídia do ano 2015
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 441
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SCM - 2017
# Do Serviço de Comunicação Multimídia do ano de 2017
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 222
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SMP - 2013
# Do Serviço Móvel Pessoal do ano de 2013
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 183
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SMP - 2014
# Do Serviço Móvel Pessoal do Ano de 2014
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 164
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SMP - 2015
# Do Serviço Móvel Pessoal do ano de 2015
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 167
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SMP - 2017
# Do Serviço Móvel Pessoal do ano de 2017
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 158
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - STFC - 2013
# Do Serviço de Telefonia Fixa Comutada do ano de 2013
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 142
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - STFC - 2014
# Do Serviço de Telefonia Fixa Comutada do ano de 2014
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 138
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - STFC - 2015
# Do Serviço de Telefonia Fixa Comutada do ano de 2015
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 150
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - STFC - 2017
# Do Serviço de Telefonia Fixa Comutada do ano de 2017
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 135
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - TV - 2013
# Do serviço de TV por Assinatura do ano de 2013
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 116
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - TV - 2014
# Do Serviço de TV por Assinatura do ano de 2014
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 111
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - TV - 2015
# Do Serviço de TV por Assinatura do Ano de 2015
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 108
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - TV - 2017
# Do Serviço de TV por Assinatura do ano de 2017
# Catalogação: 15/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 106
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - TV - 2016
# Catalogação: 30/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 103
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SMP - 2016
# Catalogação: 30/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 120
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - STFC - 2016
# Catalogação: 30/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 122
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SCM - 2016
# Catalogação: 30/01/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 124
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - STFC - 2018
# Catalogação: 25/10/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 126
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SCM - 2018
# Catalogação: 25/10/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 120
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SMP - 2018
# Catalogação: 25/10/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 122
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - TV - 2018
# Catalogação: 25/10/2018
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 106
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - STFC - 2019
# Catalogação: 03/04/2019
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 140
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SMP - 2019
# Catalogação: 03/04/2019
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 141
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - TV - 2019
# Catalogação: 03/04/2019
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 114
# Acessar o recurso
# 🔍 Encontrado: Índice de Desempenho no Atendimento - SCM - 2019
# Catalogação: 03/04/2019
# Data de atualização do arquivo: Indisponível (Resposta diferente do código 200)
# Downloads: 167
# Acessar o recurso
