# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.read_csv(
    r"C:\Users\Mileno\Downloads\PDI\data\temp\ods_csv\SCM2016_Banda_Larga_Fixa.csv",
    encoding="utf-8-sig"
)

print(df.head())
print(df.iloc[0])
# Out:
#   GRUPO ECONÔMICO                                      VARIÁVEL    2016-01  \
# 0           ALGAR  Indicador de Desempenho no Atendimento (IDA)  94.474776
# 1         GVT (*)  Indicador de Desempenho no Atendimento (IDA)  76.479057
# 2             NET  Indicador de Desempenho no Atendimento (IDA)  78.631411
# 3              OI  Indicador de Desempenho no Atendimento (IDA)   0.000000
# 4       SERCOMTEL  Indicador de Desempenho no Atendimento (IDA)  80.377574
#
#      2016-02    2016-03     2016-04    2016-05  2016-06    2016-07    2016-08  \
# 0  93.052206  92.405439   96.660629  98.086590   94.679  95.671870  88.504193
# 1  73.902661  69.924062         NaN        NaN      NaN        NaN        NaN
# 2  79.184711  77.216504   92.306580  92.173691   91.797  91.679732  91.472236
# 3   0.000000   0.000000    0.000000   0.000000    9.601  19.589429  10.610403
# 4  87.878788  92.647059  100.000000  71.472720   60.285  86.126894  76.585695
#
#    2016-09  2016-10    2016-11    2016-12
# 0   92.209   96.390  93.290807  85.212273
# 1      NaN      NaN        NaN        NaN
# 2   93.038   92.285  85.712717  86.502207
# 3   28.725   26.837  24.617096  15.186503
# 4  100.000   83.814  82.502914  92.857143
# GRUPO ECONÔMICO                                           ALGAR
# VARIÁVEL           Indicador de Desempenho no Atendimento (IDA)
# 2016-01                                               94.474776
# 2016-02                                               93.052206
# 2016-03                                               92.405439
# 2016-04                                               96.660629
# 2016-05                                                98.08659
# 2016-06                                                  94.679
# 2016-07                                                95.67187
# 2016-08                                               88.504193
# 2016-09                                                  92.209
# 2016-10                                                   96.39
# 2016-11                                               93.290807
# 2016-12                                               85.212273
# Name: 0, dtype: object

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.read_parquet(
    r"C:\Users\Mileno\Downloads\PDI\data\staging\wide\ida_anatel\SCM2016_Banda_Larga_Fixa.parquet",
    engine="fastparquet"
)

print(df.head())
print(df.iloc[0])
print(df.dtypes)
# Out:
#   grupo_economico                                      variavel  mes_2016_01  \
# 0           ALGAR  Indicador de Desempenho no Atendimento (IDA)    94.474776
# 1         GVT (*)  Indicador de Desempenho no Atendimento (IDA)    76.479057
# 2             NET  Indicador de Desempenho no Atendimento (IDA)    78.631411
# 3              OI  Indicador de Desempenho no Atendimento (IDA)     0.000000
# 4       SERCOMTEL  Indicador de Desempenho no Atendimento (IDA)    80.377574
#
#    mes_2016_02  mes_2016_03  mes_2016_04  mes_2016_05  mes_2016_06  \
# 0    93.052206    92.405439    96.660629    98.086590       94.679
# 1    73.902661    69.924062          NaN          NaN          NaN
# 2    79.184711    77.216504    92.306580    92.173691       91.797
# 3     0.000000     0.000000     0.000000     0.000000        9.601
# 4    87.878788    92.647059   100.000000    71.472720       60.285
#
#    mes_2016_07  mes_2016_08  mes_2016_09  mes_2016_10  mes_2016_11  \
# 0    95.671870    88.504193       92.209       96.390    93.290807
# 1          NaN          NaN          NaN          NaN          NaN
# 2    91.679732    91.472236       93.038       92.285    85.712717
# 3    19.589429    10.610403       28.725       26.837    24.617096
# 4    86.126894    76.585695      100.000       83.814    82.502914
#
#    mes_2016_12 arquivo_origem modelo  ano_arquivo       _ingestion_timestamp  \
# 0    85.212273    SCM2016.ods    SCM         2016 2026-05-23 18:15:37.862886
# 1          NaN    SCM2016.ods    SCM         2016 2026-05-23 18:15:37.862886
# 2    86.502207    SCM2016.ods    SCM         2016 2026-05-23 18:15:37.862886
# 3    15.186503    SCM2016.ods    SCM         2016 2026-05-23 18:15:37.862886
# 4    92.857143    SCM2016.ods    SCM         2016 2026-05-23 18:15:37.862886
#
#   _processing_date                      _record_hash
# 0       2026-05-23  8ddefeac5c31822fe5618868f0359b12
# 1       2026-05-23  59dc687c479751ed375d5a01a3a8bb30
# 2       2026-05-23  3bce43b081b5a147ef6ce802ceef9acd
# 3       2026-05-23  4c9893689d60c2897dee18ab30cd2bec
# 4       2026-05-23  a89166f0492041b975ba8388bdb3e0e9
# grupo_economico                                                ALGAR
# variavel                Indicador de Desempenho no Atendimento (IDA)
# mes_2016_01                                                94.474776
# mes_2016_02                                                93.052206
# mes_2016_03                                                92.405439
# mes_2016_04                                                96.660629
# mes_2016_05                                                 98.08659
# mes_2016_06                                                   94.679
# mes_2016_07                                                 95.67187
# mes_2016_08                                                88.504193
# mes_2016_09                                                   92.209
# mes_2016_10                                                    96.39
# mes_2016_11                                                93.290807
# mes_2016_12                                                85.212273
# arquivo_origem                                           SCM2016.ods
# modelo                                                           SCM
# ano_arquivo                                                     2016
# _ingestion_timestamp                      2026-05-23 18:15:37.862886
# _processing_date                                          2026-05-23
# _record_hash                        8ddefeac5c31822fe5618868f0359b12
# Name: 0, dtype: object
# grupo_economico                 object
# variavel                        object
# mes_2016_01                    float64
# mes_2016_02                    float64
# mes_2016_03                    float64
# mes_2016_04                    float64
# mes_2016_05                    float64
# mes_2016_06                    float64
# mes_2016_07                    float64
# mes_2016_08                    float64
# mes_2016_09                    float64
# mes_2016_10                    float64
# mes_2016_11                    float64
# mes_2016_12                    float64
# arquivo_origem                  object
# modelo                          object
# ano_arquivo                      int32
# _ingestion_timestamp    datetime64[ns]
# _processing_date                object
# _record_hash                    object
# dtype: object
