# %% [markdown]
# # Visualização de dados dbt marts
#
# Este notebook conecta ao arquivo DuckDB usado pelo perfil dbt e exibe os resultados dos modelos analíticos.

# %%
import duckdb
import pandas as pd

con = duckdb.connect('../data/duckdb/anatel.duckdb')

tables = con.execute('SHOW TABLES').fetchdf()

display(tables)
# Out:
#                       name
# 0     mart_anatel_smp_kpis
# 1  mart_anatel_smp_summary
# 2       stg_anatel_ida_smp

# %%
# Visualizar os primeiros registros de mart_anatel_smp_summary
query_summary = 'SELECT * FROM mart_anatel_smp_summary LIMIT 20'
summary_df = con.execute(query_summary).fetchdf()
display(summary_df)
# Out:
#       grupo_economico modelo                                      variavel  \
# 0           SERCOMTEL    SMP                         Índice de Reclamações
# 1                 TIM    SMP                         Índice de Reclamações
# 2                  OI    SMP                       Quantidade de reabertas
# 3               ALGAR    SMP          Quantidade de Reclamações no Período
# 4               ALGAR    SMP      Quantidade de Sol. Resolvidas no Período
# 5               ALGAR    SMP                             Taxa de Reabertas
# 6               CLARO    SMP                 Taxa de Resolvidas no Período
# 7               ALGAR    SMP  Quantidade de Sol. Respondidas em até 5 dias
# 8               ALGAR    SMP     Quantidade de Sol. Respondidas no Período
# 9                  OI    SMP           Taxa de Respondidas em 5 dias Úteis
# 10               VIVO    SMP                Taxa de Respondidas no Período
# 11       VIACABO (**)    SMP  Indicador de Desempenho no Atendimento (IDA)
# 12                SKY    SMP                         Índice de Reclamações
# 13                NET    SMP          Quantidade de Reclamações no Período
# 14                NET    SMP  Quantidade de Sol. Respondidas em até 5 dias
# 15                NET    SMP     Quantidade de Sol. Respondidas no Período
# 16                NET    SMP                             Taxa de Reabertas
# 17            GVT (*)    SMP                Taxa de Respondidas no Período
# 18  Sercomtel Celular    SMP  Indicador de Desempenho no Atendimento (IDA)
# 19  Sercomtel Celular    SMP            Taxa de Resolvidas em 5 dias Úteis
#
#    first_competencia last_competencia  record_count    total_valor  \
# 0         2015-01-01       2019-04-01            76      19.783587
# 1         2015-01-01       2019-04-01            76     142.767595
# 2         2015-01-01       2019-04-01            88  159321.000000
# 3         2015-01-01       2019-04-01            88   48178.000000
# 4         2015-01-01       2015-12-01            12    6313.000000
# 5         2015-01-01       2019-04-01            88     645.959699
# 6         2015-01-01       2015-12-01            12    1198.931000
# 7         2016-01-01       2019-04-01            76   12701.000000
# 8         2016-01-01       2019-04-01            76   41861.000000
# 9         2016-01-01       2019-04-01            76    6424.565749
# 10        2016-01-01       2019-04-01            76    7580.452000
# 11        2016-01-01       2016-07-01            14    1193.989517
# 12        2016-01-01       2016-12-01            24      71.805248
# 13        2016-01-01       2016-12-01            24  672750.000000
# 14        2016-01-01       2016-12-01            24  193865.000000
# 15        2016-01-01       2016-12-01            24  672018.000000
# 16        2016-01-01       2016-12-01            24     173.259827
# 17        2016-01-01       2016-03-01             9     896.458000
# 18        2013-01-01       2014-12-01            24    2169.793000
# 19        2013-01-01       2014-12-01            23    2110.714000
#
#        avg_valor     min_valor     max_valor
# 0       0.260310      0.016948      1.464494
# 1       1.878521      0.317135     11.433212
# 2    1810.465909    271.000000   5108.000000
# 3     547.477273    149.000000    945.000000
# 4     526.083333    329.000000    733.000000
# 5       7.340451      0.000000     26.530612
# 6      99.910917     99.721000     99.982000
# 7     167.118421     41.000000    334.000000
# 8     550.802632    149.000000    945.000000
# 9      84.533760     74.195912     87.749000
# 10     99.742789     99.006000    100.000000
# 11     85.284966     68.284227     97.714290
# 12      2.991885      2.194000      4.190623
# 13  28031.250000  17740.000000  41766.000000
# 14   8077.708333   4987.000000  12308.000000
# 15  28000.750000  17736.000000  41763.000000
# 16      7.219159      5.328005      9.035198
# 17     99.606444     99.397000     99.931000
# 18     90.408042      4.167000    100.000000
# 19     91.770174      0.000000    100.000000

# %%
# Visualizar os primeiros registros de mart_anatel_smp_kpis
query_kpis = 'SELECT * FROM mart_anatel_smp_kpis LIMIT 20'
kpis_df = con.execute(query_kpis).fetchdf()
display(kpis_df)
# Out:
#    competencia    grupo_economico  record_count  distinct_variavel_count  \
# 0   2013-03-01       CTBC Celular             7                        7
# 1   2013-07-01       CTBC Celular             7                        7
# 2   2013-05-01  Sercomtel Celular             7                        7
# 3   2013-09-01  Sercomtel Celular             7                        7
# 4   2013-10-01  Sercomtel Celular             7                        7
# 5   2013-11-01  Sercomtel Celular             7                        7
# 6   2013-05-01               Vivo             7                        7
# 7   2013-09-01               Vivo             7                        7
# 8   2013-10-01               Vivo             7                        7
# 9   2013-11-01               Vivo             7                        7
# 10  2013-03-01         Oi Celular             2                        2
# 11  2013-07-01         Oi Celular             2                        2
# 12  2016-01-01              ALGAR            48                       12
# 13  2016-02-01              ALGAR            48                       12
# 14  2016-05-01           EMBRATEL            12                       12
# 15  2016-09-01           EMBRATEL            12                       12
# 16  2016-01-01                 OI            48                       12
# 17  2016-02-01                 OI            48                       12
# 18  2016-12-01          SERCOMTEL            36                       12
# 19  2016-12-01                TIM            36                       12
#
#      total_valor     avg_valor   last_ingestion_timestamp
# 0   8.402110e+05  1.200301e+05 2026-05-26 21:11:32.141226
# 1   9.240557e+05  1.320080e+05 2026-05-26 21:11:32.141226
# 2   6.860001e+04  9.800002e+03 2026-05-26 21:11:32.141226
# 3   6.417065e+04  9.167236e+03 2026-05-26 21:11:32.141226
# 4   6.385075e+04  9.121535e+03 2026-05-26 21:11:32.141226
# 5   6.255474e+04  8.936391e+03 2026-05-26 21:11:32.141226
# 6   7.612165e+07  1.087452e+07 2026-05-26 21:11:32.141226
# 7   7.664411e+07  1.094916e+07 2026-05-26 21:11:32.141226
# 8   7.740346e+07  1.105764e+07 2026-05-26 21:11:32.141226
# 9   7.768883e+07  1.109840e+07 2026-05-26 21:11:32.141226
# 10  4.952405e+07  2.476203e+07 2026-05-26 21:11:32.141226
# 11  4.986289e+07  2.493145e+07 2026-05-26 21:11:32.141226
# 12  2.820227e+06  5.875473e+04 2026-05-26 21:11:58.226602
# 13  2.856172e+06  5.950359e+04 2026-05-26 21:11:58.226602
# 14  1.142669e+07  9.522244e+05 2026-05-26 21:11:47.830536
# 15  1.133032e+07  9.441929e+05 2026-05-26 21:11:47.830536
# 16  7.129581e+07  1.485329e+06 2026-05-26 21:11:58.226602
# 17  7.125408e+07  1.484460e+06 2026-05-26 21:11:58.226602
# 18  5.029403e+05  1.397056e+04 2026-05-26 21:11:58.226602
# 19  6.474530e+07  1.798481e+06 2026-05-26 21:11:58.226602
